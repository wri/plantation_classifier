# %%
import hickle as hkl
import numpy as np

# %%
df = hkl.load('../data/00001.hkl', safe=True)

# %%
df
# Out:
# array([[[[0.20356455, 0.02638063],
#          [0.20356455, 0.02638063],
#          [0.1541011 , 0.03217175],
#          ...,
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686]],
#
#         [[0.20356455, 0.02638063],
#          [0.20356455, 0.02638063],
#          [0.1541011 , 0.03217175],
#          ...,
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686]],
#
#         [[0.13179982, 0.03630918],
#          [0.13179982, 0.03630918],
#          [0.20600343, 0.05350216],
#          ...,
#          [0.21761912, 0.03317631],
#          [0.20334691, 0.03545757],
#          [0.20334691, 0.03545757]],
#
#         ...,
#
#         [[0.18403932, 0.04058381],
#          [0.18403932, 0.04058381],
#          [0.12924528, 0.06264581],
#          ...,
#          [0.13198778, 0.04486999],
#          [0.1777133 , 0.04133686],
#          [0.1777133 , 0.04133686]],
#
# ...

# %%
df[..., 1:] = np.clip(df[..., 1:], a_min=-32.768, a_max=32.767)

# %%
df
# Out:
# array([[[[0.20356455, 0.02638063],
#          [0.20356455, 0.02638063],
#          [0.1541011 , 0.03217175],
#          ...,
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686]],
#
#         [[0.20356455, 0.02638063],
#          [0.20356455, 0.02638063],
#          [0.1541011 , 0.03217175],
#          ...,
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686],
#          [0.16309685, 0.02050686]],
#
#         [[0.13179982, 0.03630918],
#          [0.13179982, 0.03630918],
#          [0.20600343, 0.05350216],
#          ...,
#          [0.21761912, 0.03317631],
#          [0.20334691, 0.03545757],
#          [0.20334691, 0.03545757]],
#
#         ...,
#
#         [[0.18403932, 0.04058381],
#          [0.18403932, 0.04058381],
#          [0.12924528, 0.06264581],
#          ...,
#          [0.13198778, 0.04486999],
#          [0.1777133 , 0.04133686],
#          [0.1777133 , 0.04133686]],
#
# ...
